# %%
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup
import json
from lark import Lark
import re

# %%
def Test_Crawl(url):
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    data = soup.find('div', { 'class' : 'js-store' })['data-content']
    data_json = json.loads(data)
    print(data)

# %%
Test_Crawl('https://tabs.ultimate-guitar.com/tab/tom-odell/another-love-chords-1198980')
# Out:
# {"config":{"releaseVer":"ug-web_app_0.05.31","abVariation":null,"abVariation2":null,"abVariation3":null,"abTestAccountVariation":[],"experiments":{"isPianoChordGroup":false},"urlFacebook":"https://www.ultimate-guitar.com/user/auth/oauth?service=facebook","urlGoogle":"https://www.ultimate-guitar.com/user/auth/oauth?service=google","urlApple":"https://www.ultimate-guitar.com/user/auth/oauth?service=apple","main_server":"ultimate-guitar.com","ps_server":"plus.ultimate-guitar.com","static_server":"https://tabs.ultimate-guitar.com/static","statik_cache":"_ver1668538761","staticPrefix":"/static","time":1668580986000,"isGDPRAvailable":false,"isCcpaAvailable":false,"user":{"id":0,"uuid":0,"unified_id":"1.1668580985.127766","session":{"id":"1.1668580985.1668580986","expire_duration":300,"expire_duration_dispersion":[5000,10000],"enable_refresh":true},"username":"Unregistered","iq":"","contributorPower":false},"isOfficeUser":false,"isOfficeRequest":false,"isWebp":false,"isBot":false,"is_mobile":false,"is_tablet":false,"isThemeMobile":false,"isIe":false,"socketCluster":{"serviceKey":"f0557aa8-2d06-43d9-9c16-f885bc710b97:main","channelPrefix":"f0557aa8-2d06-43d9-9c16-f885bc710b97:main#prod","hostname":"socketcluster.k8s.wsmgroup.ru","port":443,"channelName":"e2b911c3d39e5e206f13c6dab0ac7bcc"},"metricaId":18746557,"captcha_id":"6LfCo_8SAAAAALEMHnlK18j8IemlAdvmxwRnQe2v","stripeApiKey":"pk_live_4aZVHgEcj68d3uAgtisiXtZo","country":"KR","countryCode":"KR","browserName":"Python","os":"","platform":4,"browser":"{\"browser\":{\"name\":\"Python\",\"version\":\"2.28.1\"},\"device\":{\"type\":\"bot\"}}","urlUgProAppIcon":"https://tabs.ultimate-guitar.com/static/public/img/app_icons/icon_ug_pro_ver1668538761.png","withCritical":false,"analytics":{"userTrackerId":"SA=="},"braintree":{"environment":"production","tokenizationKey":"production_8htvrhhr_67vpx3rpxt6m5z7c","paypalClientId":"ASwoeikdyflPIKFAC3U34ewfFVRE5-_p6qc1TTQG9g_sHNs3RP5Sq3pE_e7V2p0VTi-nJQuIA5ApP1XH","googlePayClientId":"BCR2DN6TZPEKBZBZ"},"vimeo":{"baseImagePath":"https://cdn.ustatik.com/s3/ug.video.warm/preview/"},"hasStaticCache":0,"rtAnalytics":{"trackUrl":"/components/ab/event","trackingEnabled":true,"forceSendEvents":["Tab Favorite Add Click","Tab Rate Click","Tab View"],"tabToolLogging":true,"samplerHeartbeat":5},"xtz":{"isActive":true,"hasAccess":true,"canToggle":false,"feedbackChannel":null},"jinba":{"customTimings":[],"appLabel":"tab_page","appLabelExp":"null"},"metricaParams":{"rights":0,"proRights":0,"coursesRights":0,"u_id":"SA==","auth":"None","is_registered":0,"ab":[]}},"store":{"page":{"data":{"mobile_device":null,"show_rate_layer":false,"tab":{"id":1198980,"song_id":325077,"song_name":"Another Love","artist_id":39037,"artist_name":"Tom Odell","type":"Chords","part":"","version":1,"votes":3834,"rating":4.8854699999999997572786014643497765064239501953125,"date":"1354752001","status":"approved","preset_id":27837,"tab_access_type":"public","tp_version":0,"tonality_name":"Em","version_description":"","verified":0,"recording":{"is_acoustic":0,"tonality_name":"","performance":null,"recording_artists":[]},"artist_url":"https://www.ultimate-guitar.com/artist/tom_odell_39037","tab_url":"https://tabs.ultimate-guitar.com/tab/tom-odell/another-love-chords-1198980","date_update":"1621972642","user_id":3125106,"user_iq":71,"username":"Jacob TT","type_name":"Chords","best_pro_tab_url":"https://tabs.ultimate-guitar.com/tab/tom-odell/another-love-guitar-pro-1885004"},"backing_track_tip":false,"tab_view":{"wiki_tab":{"content":"(hold): Hold for two extra bars.\r\n\r\n[Intro]\r\n[ch]C[/ch]\r\n[ch]Em[/ch]    [ch]Am[/ch] [ch]Em[/ch]\r\n[ch]Bm[/ch]       [ch]C[/ch]\r\n[ch]Em[/ch]    [ch]Am[/ch] [ch]Em[/ch]\r\n[ch]Bm[/ch]       [ch]C[/ch] (hold)\r\n\r\n\r\n[Verse 1]\r\n\r\n[tab]                 [ch]Em[/ch]               [ch]Am[/ch]     [ch]Em[/ch]\r\nI wanna take you somewhere so you know I care,[/tab]\r\n[tab]            [ch]Bm[/ch]                    [ch]C[/ch]\r\nbut it's so cold and I don't ...

# %%
def Crawl_One(url):
    html = requests.get(url).text
    soup = BeautifulSoup(html, 'html.parser')
    data = soup.find('div', { 'class' : 'js-store' })['data-content']
    data_json = json.loads(data)
    data_new = {
        'title': data_json['store']['page']['data']['tab']['song_name'],
        'artist': data_json['store']['page']['data']['tab']['artist_name'],
        'key': data_json['store']['page']['data']['tab']['tonality_name'],
        'chords': data_json['store']['page']['data']['tab_view']['wiki_tab']['content']
    }
    try:
        data_new['capo'] = data_json['store']['page']['data']['tab_view']['meta']['capo']
    except KeyError:
        data_new['capo'] = ''
    return data_new

# %%
def Parse_Links(start, stop):
    for i in range(start, stop):
        url = "https://www.ultimate-guitar.com/explore?page=" + str(i) + "&type[]=Chords"
        html = requests.get(url).text
        soup = BeautifulSoup(html, 'html.parser')
        data = soup.find('div', { 'class' : 'js-store' })['data-content']
        data_json = json.loads(data)
        links = []
        for tab in data_json['store']['page']['data']['data']['tabs']:
            links.append(tab['tab_url'])
        print(f"Parsed links for page {i}. Current number of links: {len(links)}")
    return links

# %%
def Parse_Song(song):
    lines = []
    tag_verification_needed = False
    current_opening_tag = ''
    current_closing_tag = ''
    parsing_opening_tag = False
    parsing_closing_tag = False
    current_content = ''
    parsing_content = False
    current_line = []
    for char in song:
        if char == "[":
            tag_verification_needed = True
            parsing_content = False
            # print('opened a tag - verification needed')
        elif char == "]": # 태그가 닫혔다
            if parsing_opening_tag: # 오프닝태그가 닫혔다
                parsing_opening_tag = False
                if current_opening_tag == 'ch':
                    parsing_content = True
                # print('closed opening tag: ' + current_opening_tag)
            else: # 클로징태그가 닫혔다
                parsing_closing_tag = False
                # print('closed closing tag: ' + current_closing_tag)
                if current_closing_tag == 'ch': # 코드가 닫혔을경우
                    current_line.append(current_content)
                    # print('pushing new chord: ' + current_content)
                    current_opening_tag = ''
                    current_closing_tag = ''
                    current_content = ''
                elif current_closing_tag == 'tab': # 탭이 닫혔을경우
                    if current_line != []:
                        lines.append(current_line)
                    # print('pushing new line: ', current_line)
                    current_opening_tag = ''
                    current_closing_tag = ''
                    current_content = ''
                    current_line = []
        elif char == "/":
            if tag_verification_needed:
                tag_verification_needed = False
                parsing_opening_tag = False
                parsing_closing_tag = True
                # print('--tag is closing tag')
            elif parsing_content:
                current_content += char
        else: # 그냥 글자가 왔다
            if char != ' ':
                if tag_verification_needed:
                    if len(current_opening_tag) > 0: # 이미 오프닝태그가 있는 경우 내용 삭제후 새로 파싱
                        current_opening_tag = ''
                        current_content = ''
                        tag_verification_needed = False
                        parsing_opening_tag = True
                        current_opening_tag += char
                    else:
                        tag_verification_needed = False
                        parsing_opening_tag = True
                        parsing_closing_tag = False
                        current_opening_tag += char
                    # print('--tag is opening tag')
                elif parsing_opening_tag:
                    current_opening_tag += char
                elif parsing_closing_tag:
                    current_closing_tag += char
                elif parsing_content:
                    current_content += char
    return lines

# %%
def Crawl(start, stop):
    songs = []
    for url in Parse_Links(start, stop):
        print(f'Crawling from url: {url}')
        data = Crawl_One(url)
        data['chords'] = Parse_Song(data['chords'])
        print('Succesfully parsed song.')
        songs.append(data)
    print(songs)
    
Crawl(1,2)
# Out:
# Parsed links for page 1. Current number of links: 50
# Crawling from url: https://tabs.ultimate-guitar.com/tab/elvis-presley/cant-help-falling-in-love-chords-1086983
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/ed-sheeran/perfect-chords-1956589
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/jeff-buckley/hallelujah-chords-198052
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/tom-odell/another-love-chords-1198980
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/eagles/hotel-california-chords-46190
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/radiohead/creep-chords-4169
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/wham/last-christmas-chords-169565
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/coldplay/yellow-chords-114080
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/vance-joy/riptide-chords-1237247
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/oasis/wonderwall-chords-27596
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/mariah-carey/all-i-want-for-christmas-is-you-chords-903566
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/keane/somewhere-only-we-know-chords-109970
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/zach-bryan/something-in-the-orange-chords-4012711
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/passenger/let-her-go-chords-1137467
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/the-animals/house-of-the-rising-sun-chords-18688
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-1101747
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/misc-soundtrack/a-star-is-born-shallow-chords-2488086
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/stephen-sanchez/until-i-found-you-chords-3860363
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/frank-sinatra/fly-me-to-the-moon-chords-335196
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/taylor-swift/anti-hero-chords-4392359
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/bruno-mars/when-i-was-your-man-chords-1198871
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/joji/glimpse-of-us-chords-4226839
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/coldplay/viva-la-vida-chords-675427
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/pixies/where-is-my-mind-chords-89446
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/billie-eilish/tv-chords-4224094
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/pink-floyd/wish-you-were-here-chords-44555
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/the-cranberries/zombie-chords-844902
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/gnarls-barkley/crazy-chords-377909
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/oasis/dont-look-back-in-anger-chords-6097
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/misc-christmas/jingle-bells-chords-273336
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/john-denver/take-me-home-country-roads-chords-57606
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/bobby-helms/jingle-bell-rock-chords-1443245
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/the-beatles/yesterday-chords-17450
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/adele/someone-like-you-chords-1006751
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/goo-goo-dolls/iris-chords-54512
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/john-legend/all-of-me-chords-1248578
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/ed-sheeran/thinking-out-loud-chords-1486860
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/judy-garland/have-yourself-a-merry-little-christmas-chords-762486
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/grover-washington-jr-/just-the-two-of-us-chords-663141
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/taylor-swift/youre-on-your-own-kid-chords-4393385
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/billie-eilish/happier-than-ever-chords-3592094
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/john-lennon/imagine-chords-9306
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/creedence-clearwater-revival/have-you-ever-seen-the-rain-chords-56479
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab/ed-sheeran/photograph-chords-1493446
# Succesfully parsed song.
# Crawling from url: https://tabs.ultimate-guitar.com/tab